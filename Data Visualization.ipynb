# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.arange(20)
y = np.random.normal(10, 1, 20)
z = np.random.normal(10, 2, 20)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, color = 'blue')
ax.set_title('Line chart')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, label = 'Thing #1')
ax.plot(x, z, label = 'Thing #2')
ax.legend()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, marker = '.', c = '#FF0000')
ax.set_ylabel('$$$ Money', fontsize = 10)
ax.set_xlabel('Years', fontsize = 20)
fig.savefig('figure.png', dpi = 300)

# %%
fig2 = plt.figure(figsize = (15,5))

a = fig2.add_subplot(131)
a.scatter(x, y)
a.set_title('Scatter plot')

b = fig2.add_subplot(132)
b.hist(y)
b.set_title('Histogram')

c = fig2.add_subplot(133)
c.boxplot([y, z])
c.set_title('Box plot')

fig2.suptitle('Visualition')
# Out:
# Text(0.5, 0.98, 'Visualition')

# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.plot.scatter(x = 'Age', y = 'Fare', title = 'Scatter plot');

# %%
data[['Age', 'Fare']].plot.line(title = 'Line Chart');

# %%
data['Age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Pclass'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Pclass'].value_counts().sort_index().plot.barh()
# Out:
# <AxesSubplot:>

# %%
data['Age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")

# %%
sns.scatterplot(x = 'Age', y = 'Fare', hue = 'Survived', data = data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.lineplot(data = data [['Fare','Age']])
# Out:
# <AxesSubplot:>

# %%
sns.distplot(data['Age'], bins = 10, kde = True)
# Out:
# /Users/macmini/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.histplot(data['Age'], bins = 10, kde = True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.displot(data['Age'], bins = 10, kde = True)

# %%
sns.countplot(data['Embarked'])
# Out:
# /Users/macmini/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
sns.boxplot('Age', 'Sex', data = data)
# Out:
# /Users/macmini/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
penguins = sns.load_dataset("penguins")
sns.pairplot(penguins)

# %%
sns.pairplot(penguins, hue = 'species')

# %%
sns.pairplot(penguins, kind = 'kde')
